# %%
# %matplotlib inline
import sys
from types import ModuleType
from importlib import reload

# %%
SRC_PATH = "./src"
sys.path.append(SRC_PATH)
import main

# %%
def rreload(module):
    """Recursively reload modules."""
    reload(module)
    for attribute_name in dir(module):
        attribute = getattr(module, attribute_name)
        if type(attribute) is ModuleType and attribute.__file__.startswith(SRC_PATH):
            rreload(attribute)

# %%
rreload(main)
main.main()
# Out:
# data/sample/sample.png
# (1123, 1588, 3)
# gmax: 1107.9585
# adding layer 1 (1123, 1588)
# adding layer 2 (1122, 1587)
# adding layer 3 (1120, 1585)
# adding layer 4 (1116, 1581)
